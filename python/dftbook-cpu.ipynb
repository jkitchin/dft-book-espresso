# %%
# !pip install --upgrade dftbook
import dftbook
dftbook.setup_colab() # Regular CPU setup
# Out:
# Collecting dftbook
#   Downloading https://files.pythonhosted.org/packages/a3/63/891b94b21584b512ac0020ea7dba3a3f8178569033a5d86ad4ea326a21d8/dftbook-0.0.4-py3-none-any.whl
# Installing collected packages: dftbook
# Successfully installed dftbook-0.0.4
# Please be patient. This takes about 30 seconds.
# Installing ASE
# Installing ase-espresso
# Installing pseudopotentials
# Renaming pseudopotentials
# Almost there, setting environment pseudopotential path
# Installing quantum espresso
# Setup is complete. Please visit https://github.com/jkitchin/dft-book-espresso to find the tutorials.
# Installation took 30.7 seconds

# %%
from ase import Atoms, Atom
from espresso import Espresso

co = Atoms([Atom('C', [0, 0, 0]),
            Atom('O', [1.2, 0, 0])],
            cell=(6., 6., 6.))

#Use QE as a single-point calculator (just SCF)
calc = Espresso(pw=350.0,
                calculation='scf',
                xc='PBE')

co.set_calculator(calc)

import time
t0 = time.time()
print('energy = {0} eV'.format(co.get_potential_energy()))
print(co.get_forces())
print(f'Elapsed time: {time.time() - t0} seconds')
# Out:
# energy = -593.6960610598508 eV
# [[ 5.46386614  0.          0.        ]
#  [-5.46386614  0.          0.        ]]
# Elapsed time: 8.733170986175537 seconds
